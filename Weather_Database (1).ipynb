# %%
#Import the dependencies
import numpy as np
from citipy import citipy
import requests
import pandas as pd
from config import weather_api_key

# %%
# Create a set of 2000 Latitudes and Longitudes

lats = np.random.uniform(-90, 90, 2000)
lngs =np.random.uniform(-180, 180, 2000)
lats_lngs = zip(lats, lngs)

coordinates = list(lats_lngs)

# %%
# Initialize the cities list
cities = []
# Identify the nearest city for each Latitude and longitute Combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    if city not in cities:
        
        cities.append(city)

# %%
len(cities)
# Out:
# 751

# %%
len(coords)
# Out:
# 2000

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning Data
print("Beginning Data Retrieval     ")
print(" ")

# Create counters.
record_count = 1
set_count = 1

# Loop thorugh all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count = 1
    # Create the parameters.
    params = {"q" : city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    #Add 1 to the record count.
    record_count+=1
    
    #API request for each city.
    try:
        
        city_weather = requests.get(url, params=params).json()
    
        #Parse Data
    
        city_lat = city_weather["coord"]["lat"]
    
        city_lng = city_weather["coord"]["lon"]
    
        city_country = city_weather["sys"]["country"]
    
        city_max_temp = city_weather["main"]["temp_max"]
    
        city_humidity = city_weather["main"]["humidity"]
    
        city_clouds = city_weather["clouds"]["all"]
    
        city_wind = city_weather["wind"]["speed"]
        
        city_weather_desc = str(city_weather["weather"][0]["description"])
    
    
    # Add the city information into the city_data list
    
        city_data.append({
        "City": city[0].title(),
        "Country": city_country,
        "Lat": city_lat,
        "Lng":city_lng,
        "Max Temp": city_max_temp,
        "Humidity": city_humidity,
        "Wind Speed": city_wind,
        "Cloudiness": city_clouds,
        "Current Description": city_weather_desc})
    
    # If there's an error skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
        print("------------")
        print("Data Retrieval Complete    ")
        print("------------")
# Out:
# Beginning Data Retrieval
#
# Processing Record 1 of the Set 1 | p
# Processing Record 2 of the Set 1 | u
# Processing Record 3 of the Set 1 | h
# Processing Record 4 of the Set 1 | q
# Processing Record 5 of the Set 1 | t
# City not found. Skipping...
# ------------
# Data Retrieval Complete
# ------------
# Processing Record 6 of the Set 1 | s
# Processing Record 7 of the Set 1 | s
# Processing Record 8 of the Set 1 | m
# Processing Record 9 of the Set 1 | h
# Processing Record 10 of the Set 1 | t
# Processing Record 11 of the Set 1 | b
# Processing Record 12 of the Set 1 | c
# Processing Record 13 of the Set 1 | j
# Processing Record 14 of the Set 1 | r
# Processing Record 15 of the Set 1 | p
# Processing Record 16 of the Set 1 | p
# Processing Record 17 of the Set 1 | m
# Processing Record 18 of the Set 1 | t
# City not found. Skipping...
# ------------
# Data Retrieval Complete
# ------------
# Processing Record 19 of the Set 1 | a
# Processing Record 20 of the Set 1 | c
# ...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#   City Country      Lat       Lng  Max Temp  Humidity  Wind Speed  Cloudiness  \
# 0    P      US  45.6721 -118.7886     64.63        60        5.99         100
# 1    U      AR -54.8000  -68.3000     35.26        69        8.05           0
# 2    H      JP  35.7333  140.8333     72.28        73       10.27          73
# 3    Q      VN  15.1167  108.8000     89.85        57        3.98          98
# 4    S      RU  60.0625   71.4789     51.93        60       10.36           9
# 5    S      CA  51.2260  -58.6502     44.74        97        7.76         100
# 6    M      DE  51.5000    8.1333     58.53        77        5.84         100
# 7    H      CA  60.7522 -137.5108     55.35        26       11.50         100
# 8    T      CA  69.4541 -133.0374     19.40        79       12.66         100
# 9    B      AU -33.6500  115.3333     57.96        84       16.37          94
#
#   Current Description
# 0     overcast clouds
# 1           clear sky
# 2       broken clouds
# ...

# %%
output_data_file = "WeatherPy_Database.csv"
df.to_csv(C:\Users\KrystleWest\Desktop\WeatherPy_Database.csv)
# Out:
#   File "C:\Users\KRYSTL~1\AppData\Local\Temp/ipykernel_10640/1835995577.py", line 2
#     df.to_csv(C:\Users\KrystleWest\Desktop\WeatherPy_Database.csv)
#                ^
# SyntaxError: invalid syntax
